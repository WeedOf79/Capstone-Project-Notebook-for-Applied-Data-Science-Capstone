# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# # ******** Part 1 ********

# %% [markdown]
# ### Retrieving data from Wikipedia and putting it in a dataframe

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
Soup = BeautifulSoup(requests.get(URL).content, 'html.parser')
table_contents = []
table = Soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text == 'Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /', ',')).replace(')', ' ')).strip(' ')
        table_contents.append(cell)

# %%
df = pd.DataFrame(table_contents)
df['Borough'] = df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})
df.shape
df
# Out:
#     PostalCode                Borough  \
# 0          M3A             North York
# 1          M4A             North York
# 2          M5A       Downtown Toronto
# 3          M6A             North York
# 4          M7A           Queen's Park
# ..         ...                    ...
# 98         M8X              Etobicoke
# 99         M4Y       Downtown Toronto
# 100        M7Y  East Toronto Business
# 101        M8Y              Etobicoke
# 102        M8Z              Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4                        Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100                                     Enclave of M4L
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %% [markdown]
# # ******** Part 2 ********

# %% [markdown]
# ### Adding the coordinates to the dataset

# %%
df_coords = pd.read_csv(r'Geospatial_Coordinates.csv')
toronto_data = df.set_index('PostalCode').join(df_coords.set_index('Postal Code'))
toronto_data
# Out:
#                           Borough  \
# PostalCode
# M3A                    North York
# M4A                    North York
# M5A              Downtown Toronto
# M6A                    North York
# M7A                  Queen's Park
# ...                           ...
# M8X                     Etobicoke
# M4Y              Downtown Toronto
# M7Y         East Toronto Business
# M8Y                     Etobicoke
# M8Z                     Etobicoke
#
#                                                  Neighborhood   Latitude  \
# PostalCode
# M3A                                                 Parkwoods  43.753259
# M4A                                          Victoria Village  43.725882
# M5A                                 Regent Park, Harbourfront  43.654260
# M6A                          Lawrence Manor, Lawrence Heights  43.718518
# M7A                             Ontario Provincial Government  43.662301
# ...                                                       ...        ...
# M8X             The Kingsway, Montgomery Road, Old Mill North  43.653654
# M4Y                                      Church and Wellesley  43.665860
# M7Y                                            Enclave of M4L  43.662744
# M8Y         Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258
# M8Z         Mimico NW, The Queensway West, South of Bloor,...  43.628841
#
#             Longitude
# PostalCode
# M3A        -79.329656
# M4A        -79.315572
# M5A        -79.360636
# M6A        -79.464763
# M7A        -79.389494
# ...               ...
# M8X        -79.506944
# M4Y        -79.383160
# M7Y        -79.321558
# M8Y        -79.498509
# M8Z        -79.520999
#
# [103 rows x 4 columns]

# %% [markdown]
# # ******** Part 3 ********

# %% [markdown]
# ### Displaying the dataset as a map with markers

# %%
# !pip install geopy
from geopy.geocoders import Nominatim
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from geopy.geocoders import Nominatim
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
# Out:
# Requirement already satisfied: geopy in c:\users\rio25\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\rio25\anaconda3\lib\site-packages (from geopy) (1.50)

# %%
# Retrieve coordinates for Toronto
address = 'Toronto'
geolocator = Nominatim(user_agent = "toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))

# Plot a map of Toronto with markers for each neighborhood
map_toronto = folium.Map(location = [latitude, longitude], zoom_start = 10)
for lat, lng, borough, neighborhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Borough'], toronto_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, lng],
        radius = 4,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.5,
        parse_html = False).add_to(map_toronto)
map_toronto
# Out:
# The geograpical coordinates of Toronto are 43.6534817, -79.3839347.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fb7cd13226de468ab05d517a59eac7dc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fb7cd13226de468ab05d517a59eac7dc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fb7cd13226de468ab05d517a59eac7dc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fb7cd13226de468ab05d517a59eac7dc%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Using Foursquare to retrieve venues in the neighborhoods

# %%
# PLEASE REPLACE THESE STRINGS WITH YOUR FOURSQUARE'S PERSONAL ACCOUNT
CLIENT_ID = '...'
CLIENT_SECRET = '...'
VERSION = '20180605'
LIMIT = 100

# %%
# Function that retrieves data from a neighborhood

def getNearbyVenues(names, latitudes, longitudes, radius = 500):
    venues_list = []
    for name, lat, lng in zip(names, latitudes, longitudes):
        print("Processing", name)
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID,
            CLIENT_SECRET,
            VERSION,
            lat,
            lng,
            radius,
            LIMIT)
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        # return only relevant information for each nearby venue
        venues_list.append([(
            name,
            lat,
            lng,
            v['venue']['name'],
            v['venue']['location']['lat'],
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood',
                  'Neighborhood Latitude',
                  'Neighborhood Longitude',
                  'Venue',
                  'Venue Latitude',
                  'Venue Longitude',
                  'Venue Category']
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names = toronto_data['Neighborhood'],
                                   latitudes = toronto_data['Latitude'],
                                   longitudes = toronto_data['Longitude']
                                  )
print('\n\nThere are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# Processing Parkwoods
# Processing Victoria Village
# Processing Regent Park, Harbourfront
# Processing Lawrence Manor, Lawrence Heights
# Processing Ontario Provincial Government
# Processing Islington Avenue
# Processing Malvern, Rouge
# Processing Don Mills North
# Processing Parkview Hill, Woodbine Gardens
# Processing Garden District, Ryerson
# Processing Glencairn
# Processing West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Processing Rouge Hill, Port Union, Highland Creek
# Processing Don Mills South
# Processing Woodbine Heights
# Processing St. James Town
# Processing Humewood-Cedarvale
# Processing Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Processing Guildwood, Morningside, West Hill
# Processing The Beaches
# Processing Berczy Park
# Processing Caledonia-Fairbanks
# Processing Woburn
# Processing Leaside
# Processing Central Bay Street
# Processing Christie
# Processing Cedarbrae
# Processing Hillcrest Village
# Processing Bathurst Manor, Wilson Heights, Downsview North
# Processing Thorncliffe Park
# Processing Richmond, Adelaide, King
# Processing Dufferin, Dovercourt Village
# Processing Scarborough Village
# Processing Fairview, Henry Farm, Oriole
# Processing Northwood Park, York University
# Processing The Danforth  East
# Processing Harbourfront East, Union Station, Toronto Islands
# Processing Little Portugal, Trinity
# Processing Kennedy Park, Ionview, East Birchmount Park
# Processing Bayview Village
# Processing Downsview East
# Processing The Danforth West, Riverdale
# Processing Toronto Dominion Centre, Design Exchange
# Processing Brockton, Parkdale Village, Exhibition Place
# Processing Golden Mile, Clairlea, Oakridge
# Processing York Mills, Silver Hills
# Processing Downsview West
# Processing India Bazaar, The Beaches West
# Processing Commerce Court, Victoria Hotel
# Processing North Park, Maple Leaf Park, Upwood Park
# Processing Humber Summit
# Processing Cliffside, Cliffcrest, Scarborough Village West
# Processing Willowdale, Newtonbrook
# Processing Downsview Central
# Processing Studio District
# Processing Bedford Park, Lawrence Manor East
# Processing Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Processing Humberlea, Emery
# Processing Birch Cliff, Cliffside West
# Processing Willowdale South
# Processing Downsview Northwest
# Processing Lawrence Park
# Processing Roselawn
# Processing Runnymede, The Junction North
# Processing Weston
# Processing Dorset Park, Wexford Heights, Scarborough Town Centre
# Processing York Mills West
# Processing Davisville North
# Processing Forest Hill North & West
# Processing High Park, The Junction South
# Processing Westmount
# Processing Wexford, Maryvale
# Processing Willowdale West
# Processing North Toronto West
# Processing The Annex, North Midtown, Yorkville
# Processing Parkdale, Roncesvalles
# Processing Enclave of L4W
# Processing Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Processing Agincourt
# Processing Davisville
# Processing University of Toronto, Harbord
# Processing Runnymede, Swansea
# Processing Clarks Corners, Tam O'Shanter, Sullivan
# Processing Moore Park, Summerhill East
# Processing Kensington Market, Chinatown, Grange Park
# Processing Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Processing Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Processing CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Processing New Toronto, Mimico South, Humber Bay Shores
# Processing South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Processing Steeles West, L'Amoreaux West
# Processing Rosedale
# Processing Enclave of M5E
# Processing Alderwood, Long Branch
# Processing Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale
# Processing Upper Rouge
# Processing St. James Town, Cabbagetown
# Processing First Canadian Place, Underground city
# Processing The Kingsway, Montgomery Road, Old Mill North
# Processing Church and Wellesley
# Processing Enclave of M4L
# Processing Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Processing Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
#
#
# There are 276 uniques categories.

# %% [markdown]
# ### Encoding and grouping the neighborhoods

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix = "", prefix_sep = "")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]
toronto_onehot.shape
# Out:
# (2119, 276)

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.shape
# Out:
# (100, 276)

# %%
# Function to retrieve the most common venues given a certain group
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending = False)
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 5
indicators = ['st', 'nd', 'rd']
# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind + 1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind + 1))
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns = columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']
for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)
neighborhoods_venues_sorted
# Out:
#                                          Neighborhood   1st Most Common Venue  \
# 0                                           Agincourt                  Lounge
# 1                              Alderwood, Long Branch             Pizza Place
# 2     Bathurst Manor, Wilson Heights, Downsview North                    Bank
# 3                                     Bayview Village                    Café
# 4                   Bedford Park, Lawrence Manor East          Sandwich Place
# 5                                         Berczy Park             Coffee Shop
# 6                         Birch Cliff, Cliffside West                    Café
# 7        Brockton, Parkdale Village, Exhibition Place                    Café
# 8   CN Tower, King and Spadina, Railway Lands, Har...        Airport Terminal
# 9                                 Caledonia-Fairbanks                    Park
# 10                                          Cedarbrae      Athletics & Sports
# 11                                 Central Bay Street             Coffee Shop
# 12                                           Christie           Grocery Store
# 13                               Church and Wellesley             Coffee Shop
# 14  Clairville, Humberwood, Woodbine Downs, West H...              Truck Stop
# 15            Clarks Corners, Tam O'Shanter, Sullivan    Fast Food Restaurant
# 16    Cliffside, Cliffcrest, Scarborough Village West                   Motel
# 17                     Commerce Court, Victoria Hotel             Coffee Shop
# 18                                         Davisville          Sandwich Place
# 19                                   Davisville North                    Park
# 20   Del Ray, Mount Dennis, Keelsdale and Silverthorn              Restaurant
# 21                                    Don Mills North                     Gym
# 22                                    Don Mills South              Restaurant
# 23  Dorset Park, Wexford Heights, Scarborough Town...       Indian Restaurant
# 24                                  Downsview Central          Baseball Field
# 25                                     Downsview East                    Park
# 26                                Downsview Northwest      Athletics & Sports
# 27                                     Downsview West           Grocery Store
# 28                       Dufferin, Dovercourt Village                  Bakery
# 29                                     Enclave of L4W             Coffee Shop
# 30                                     Enclave of M4L      Light Rail Station
# 31                                     Enclave of M5E             Coffee Shop
# 32  Eringate, Bloordale Gardens, Old Burnhamthorpe...       Convenience Store
# 33                       Fairview, Henry Farm, Oriole          Clothing Store
# 34             First Canadian Place, Underground city             Coffee Shop
# 35                           Forest Hill North & West        Sushi Restaurant
# 36                           Garden District, Ryerson             Coffee Shop
# 37                                          Glencairn                    Park
# 38                    Golden Mile, Clairlea, Oakridge                  Bakery
# 39                  Guildwood, Morningside, West Hill              Restaurant
# 40  Harbourfront East, Union Station, Toronto Islands             Coffee Shop
# 41                      High Park, The Junction South                    Café
# 42                                  Hillcrest Village    Fast Food Restaurant
# 43                                      Humber Summit  Furniture / Home Store
# 44                                   Humberlea, Emery          Baseball Field
# 45                                 Humewood-Cedarvale                   Field
# 46                     India Bazaar, The Beaches West                    Park
# 47        Kennedy Park, Ionview, East Birchmount Park        Department Store
# 48          Kensington Market, Chinatown, Grange Park                    Café
# 49  Kingsview Village, St. Phillips, Martin Grove ...                    Park
# 50                   Lawrence Manor, Lawrence Heights          Clothing Store
# 51                                      Lawrence Park                    Park
# 52                                            Leaside             Coffee Shop
# 53                           Little Portugal, Trinity                     Bar
# 54                                     Malvern, Rouge    Fast Food Restaurant
# 55  Milliken, Agincourt North, Steeles East, L'Amo...                    Park
# 56  Mimico NW, The Queensway West, South of Bloor,...           Grocery Store
# 57                        Moore Park, Summerhill East                    Park
# 58       New Toronto, Mimico South, Humber Bay Shores                     Gym
# 59           North Park, Maple Leaf Park, Upwood Park        Basketball Court
# 60                                 North Toronto West             Coffee Shop
# 61                    Northwood Park, York University  Furniture / Home Store
# 62  Old Mill South, King's Mill Park, Sunnylea, Hu...          Baseball Field
# 63                      Ontario Provincial Government             Coffee Shop
# 64                             Parkdale, Roncesvalles          Breakfast Spot
# 65                    Parkview Hill, Woodbine Gardens             Pizza Place
# 66                                          Parkwoods       Food & Drink Shop
# 67                          Regent Park, Harbourfront             Coffee Shop
# 68                           Richmond, Adelaide, King             Coffee Shop
# 69                                           Rosedale                    Park
# 70                                           Roselawn    Fast Food Restaurant
# 71             Rouge Hill, Port Union, Highland Creek                     Bar
# 72                                 Runnymede, Swansea             Coffee Shop
# 73                      Runnymede, The Junction North                 Brewery
# 74                                Scarborough Village           Jewelry Store
# 75  South Steeles, Silverstone, Humbergate, Jamest...           Grocery Store
# 76                                     St. James Town             Coffee Shop
# 77                        St. James Town, Cabbagetown             Coffee Shop
# 78                      Steeles West, L'Amoreaux West    Fast Food Restaurant
# 79                                    Studio District             Coffee Shop
# 80  Summerhill West, Rathnelly, South Hill, Forest...             Coffee Shop
# 81                The Annex, North Midtown, Yorkville                    Café
# 82                                        The Beaches       Health Food Store
# 83                                 The Danforth  East                    Park
# 84                       The Danforth West, Riverdale        Greek Restaurant
# 85      The Kingsway, Montgomery Road, Old Mill North                   River
# 86                                   Thorncliffe Park          Sandwich Place
# 87           Toronto Dominion Centre, Design Exchange             Coffee Shop
# 88                     University of Toronto, Harbord                    Café
# 89                                   Victoria Village            Hockey Arena
# 90  West Deane Park, Princess Gardens, Martin Grov...     Filipino Restaurant
# 91                                          Westmount             Pizza Place
# 92                                             Weston                    Park
# 93                                  Wexford, Maryvale              Smoke Shop
# 94                                   Willowdale South        Ramen Restaurant
# 95                                    Willowdale West                Pharmacy
# 96                            Willowdale, Newtonbrook               Piano Bar
# 97                                             Woburn             Coffee Shop
# 98                                   Woodbine Heights              Beer Store
# 99                                    York Mills West                    Park
#
#           2nd Most Common Venue       3rd Most Common Venue  \
# 0                  Skating Rink              Breakfast Spot
# 1                    Playground                Skating Rink
# 2                   Coffee Shop           Mobile Phone Shop
# 3            Chinese Restaurant         Japanese Restaurant
# 4            Italian Restaurant                  Restaurant
# 5                  Cocktail Bar                      Bakery
# 6         General Entertainment                Skating Rink
# 7                   Coffee Shop                      Bakery
# 8                Airport Lounge             Harbor / Marina
# 9                 Women's Store         Dumpling Restaurant
# 10          Fried Chicken Joint            Hakka Restaurant
# 11                         Café          Italian Restaurant
# 12                         Café                        Park
# 13             Sushi Restaurant         Japanese Restaurant
# 14          Rental Car Location               Garden Center
# 15                  Pizza Place                 Gas Station
# 16                 Skating Rink         American Restaurant
# 17                   Restaurant                       Hotel
# 18                  Pizza Place                Dessert Shop
# 19                  Pizza Place                       Hotel
# 20               Discount Store              Sandwich Place
# 21         Caribbean Restaurant         Japanese Restaurant
# 22                          Gym                 Coffee Shop
# 23                    Pet Store       Vietnamese Restaurant
# 24                   Food Truck            Business Service
# 25             Business Service                     Airport
# 26                 Liquor Store              Discount Store
# 27                         Park                       Hotel
# 28                     Pharmacy                 Music Venue
# 29                        Hotel                         Gym
# 30                  Yoga Studio               Auto Workshop
# 31           Seafood Restaurant                Cocktail Bar
# 32                     Pharmacy                Liquor Store
# 33                  Coffee Shop        Fast Food Restaurant
# 34                         Café                       Hotel
# 35           Mexican Restaurant               Jewelry Store
# 36               Clothing Store                       Hotel
# 37                       Bakery            Sushi Restaurant
# 38                 Soccer Field                Intersection
# 39                         Bank         Rental Car Location
# 40                     Aquarium                        Café
# 41           Mexican Restaurant             Thai Restaurant
# 42                  Golf Course                     Dog Run
# 43                   Restaurant                 Pizza Place
# 44  Eastern European Restaurant         Distribution Center
# 45                 Hockey Arena                       Trail
# 46               Sandwich Place        Fast Food Restaurant
# 47            Convenience Store          Chinese Restaurant
# 48                  Coffee Shop       Vietnamese Restaurant
# 49            Mobile Phone Shop              Sandwich Place
# 50            Accessories Store      Furniture / Home Store
# 51                     Bus Line                 Swim School
# 52          Sporting Goods Shop                        Bank
# 53                  Coffee Shop                  Restaurant
# 54          Dumpling Restaurant              Discount Store
# 55          Arts & Crafts Store                Intersection
# 56                  Social Club              Discount Store
# 57                        Trail                  Restaurant
# 58                  Coffee Shop        Fast Food Restaurant
# 59                         Park  Construction & Landscaping
# 60               Clothing Store                 Yoga Studio
# 61                  Coffee Shop              Massage Studio
# 62             Business Service              Farmers Market
# 63             Sushi Restaurant                 Yoga Studio
# 64                    Gift Shop                   Bookstore
# 65         Gym / Fitness Center                   Gastropub
# 66                         Park        Fast Food Restaurant
# 67                         Park                      Bakery
# 68                         Café                  Restaurant
# 69                   Playground                       Trail
# 70                         Pool                      Garden
# 71                Women's Store         Distribution Center
# 72                         Café            Sushi Restaurant
# 73                Grocery Store           Convenience Store
# 74                   Playground               Women's Store
# 75                  Pizza Place        Fast Food Restaurant
# 76                         Café                Cocktail Bar
# 77                  Pizza Place                        Café
# 78                     Gym Pool              Sandwich Place
# 79          American Restaurant                        Café
# 80          Fried Chicken Joint         American Restaurant
# 81               Sandwich Place                 Coffee Shop
# 82                          Pub                       Trail
# 83                 Intersection           Convenience Store
# 84                  Coffee Shop          Italian Restaurant
# 85                    Drugstore                       Diner
# 86            Indian Restaurant                 Yoga Studio
# 87                        Hotel                        Café
# 88                    Bookstore                      Bakery
# 89        Portuguese Restaurant                Intersection
# 90          Dumpling Restaurant              Discount Store
# 91               Discount Store                Intersection
# 92                Women's Store         Dumpling Restaurant
# 93               Sandwich Place           Accessories Store
# 94                  Coffee Shop               Shopping Mall
# 95                  Pizza Place                 Coffee Shop
# 96                Women's Store         Dumpling Restaurant
# 97                     Pharmacy       Korean BBQ Restaurant
# 98                 Skating Rink                 Curling Ice
# 99            Convenience Store               Women's Store
#
#             4th Most Common Venue        5th Most Common Venue
# 0       Latin American Restaurant           Falafel Restaurant
# 1                             Gym                  Coffee Shop
# 2                Sushi Restaurant                 Intersection
# 3                            Bank               Discount Store
# 4                     Coffee Shop                  Pizza Place
# 5                        Beer Bar               Farmers Market
# 6                 College Stadium                 Concert Hall
# 7                  Breakfast Spot                Grocery Store
# 8                     Coffee Shop                        Plane
# 9                  Discount Store          Distribution Center
# 10           Caribbean Restaurant                       Bakery
# 11                 Sandwich Place          Japanese Restaurant
# 12                     Restaurant                    Nightclub
# 13                     Restaurant                      Gay Bar
# 14                      Drugstore                   Donut Shop
# 15                           Bank           Italian Restaurant
# 16                  Women's Store                   Donut Shop
# 17                           Café                          Gym
# 18                            Gym                         Café
# 19              Food & Drink Shop               Sandwich Place
# 20                    Coffee Shop                Women's Store
# 21                           Café                Women's Store
# 22                  Grocery Store             Sushi Restaurant
# 23             Chinese Restaurant                  Gaming Cafe
# 24                    Event Space         Ethiopian Restaurant
# 25                  Women's Store          Dumpling Restaurant
# 26                  Grocery Store          Dumpling Restaurant
# 27                  Shopping Mall                         Bank
# 28      Middle Eastern Restaurant                  Supermarket
# 29                   Intersection    Middle Eastern Restaurant
# 30                  Garden Center                       Garden
# 31                         Bakery                   Restaurant
# 32                    Coffee Shop               Shopping Plaza
# 33                     Restaurant                Women's Store
# 34            Japanese Restaurant                   Restaurant
# 35                          Trail                Women's Store
# 36                Bubble Tea Shop           Italian Restaurant
# 37            Japanese Restaurant         Ethiopian Restaurant
# 38                           Park                Metro Station
# 39              Electronics Store               Breakfast Spot
# 40                          Hotel                   Restaurant
# 41           Fast Food Restaurant                  Flea Market
# 42       Mediterranean Restaurant                         Pool
# 43               Doner Restaurant                 Dessert Shop
# 44                        Dog Run             Doner Restaurant
# 45            Dumpling Restaurant               Discount Store
# 46                            Pub                      Brewery
# 47                     Hobby Shop                  Coffee Shop
# 48  Vegetarian / Vegan Restaurant                          Bar
# 49                  Women's Store                   Donut Shop
# 50                       Boutique        Vietnamese Restaurant
# 51                  Women's Store                   Donut Shop
# 52                   Burger Joint                Shopping Mall
# 53          Vietnamese Restaurant                         Café
# 54            Distribution Center                      Dog Run
# 55                     Playground                    Drugstore
# 56                         Bakery                Tanning Salon
# 57                            Gym                    Drugstore
# 58             Mexican Restaurant                       Bakery
# 59                         Bakery  Eastern European Restaurant
# 60                     Restaurant           Mexican Restaurant
# 61                            Bar           Miscellaneous Shop
# 62             Falafel Restaurant                  Event Space
# 63             Persian Restaurant                     Beer Bar
# 64                    Coffee Shop                   Restaurant
# 65                   Intersection               Breakfast Spot
# 66             Falafel Restaurant                  Event Space
# 67                 Breakfast Spot                         Café
# 68                            Gym               Clothing Store
# 69                     Donut Shop                        Diner
# 70                   Home Service         Ethiopian Restaurant
# 71                        Dog Run             Doner Restaurant
# 72             Italian Restaurant                          Pub
# 73                  Women's Store          Distribution Center
# 74                 Discount Store          Distribution Center
# 75                       Pharmacy                   Beer Store
# 76                      Gastropub                   Restaurant
# 77             Italian Restaurant                       Bakery
# 78                 Breakfast Spot                     Pharmacy
# 79                      Gastropub                       Bakery
# 80                   Liquor Store                         Bank
# 81                    Pizza Place                    BBQ Joint
# 82                  Women's Store                    Drugstore
# 83                  Metro Station                Women's Store
# 84         Furniture / Home Store               Ice Cream Shop
# 85                 Discount Store          Distribution Center
# 86      Middle Eastern Restaurant                 Burger Joint
# 87             Italian Restaurant                   Restaurant
# 88                            Bar          Japanese Restaurant
# 89     Financial or Legal Service                  Coffee Shop
# 90            Distribution Center                      Dog Run
# 91      Middle Eastern Restaurant               Sandwich Place
# 92                 Discount Store          Distribution Center
# 93      Middle Eastern Restaurant                       Bakery
# 94                           Café                  Pizza Place
# 95                    Supermarket                Women's Store
# 96                 Discount Store          Distribution Center
# 97                  Women's Store                    Drugstore
# 98                    Video Store           Athletics & Sports
# 99            Dumpling Restaurant               Discount Store

# %% [markdown]
# ### Clustering

# %%
kclusters = 5 # Number of predefined clusters
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters = kclusters, random_state = 0).fit(toronto_grouped_clustering)

# %%
# Cluster labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
# Merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = pd.merge(toronto_data, neighborhoods_venues_sorted, on = 'Neighborhood')

# %%
# Create map
map_clusters = folium.Map(location = [latitude, longitude], zoom_start = 10)

# Set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i * x) ** 2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html = True)
    print(type(cluster))
    folium.CircleMarker(
        [lat, lon],
        radius = 4,
        popup = label,
        color = rainbow[cluster - 1],
        fill = True,
        fill_color = rainbow[cluster - 1],
        fill_opacity = 0.5).add_to(map_clusters)
map_clusters
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_93b30f36198240c2aecd463ffcaf325d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_93b30f36198240c2aecd463ffcaf325d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_93b30f36198240c2aecd463ffcaf325d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_93b30f36198240c2aecd463ffcaf325d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
print("Cluster 1")
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# Cluster 1
#                               Neighborhood 1st Most Common Venue  \
# 11  Rouge Hill, Port Union, Highland Creek                   Bar
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 11         Women's Store   Distribution Center               Dog Run
#
#    5th Most Common Venue
# 11      Doner Restaurant

# %%
print("Cluster 2")
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# Cluster 2
#                                          Neighborhood   1st Most Common Venue  \
# 0                                           Parkwoods       Food & Drink Shop
# 1                                    Victoria Village            Hockey Arena
# 2                           Regent Park, Harbourfront             Coffee Shop
# 3                    Lawrence Manor, Lawrence Heights          Clothing Store
# 4                       Ontario Provincial Government             Coffee Shop
# 5                                      Malvern, Rouge    Fast Food Restaurant
# 6                                     Don Mills North                     Gym
# 7                     Parkview Hill, Woodbine Gardens             Pizza Place
# 8                            Garden District, Ryerson             Coffee Shop
# 9                                           Glencairn                    Park
# 10  West Deane Park, Princess Gardens, Martin Grov...     Filipino Restaurant
# 12                                    Don Mills South              Restaurant
# 13                                   Woodbine Heights              Beer Store
# 14                                     St. James Town             Coffee Shop
# 15                                 Humewood-Cedarvale                   Field
# 16  Eringate, Bloordale Gardens, Old Burnhamthorpe...       Convenience Store
# 17                  Guildwood, Morningside, West Hill              Restaurant
# 18                                        The Beaches       Health Food Store
# 19                                        Berczy Park             Coffee Shop
# 21                                             Woburn             Coffee Shop
# 22                                            Leaside             Coffee Shop
# 23                                 Central Bay Street             Coffee Shop
# 24                                           Christie           Grocery Store
# 25                                          Cedarbrae      Athletics & Sports
# 26                                  Hillcrest Village    Fast Food Restaurant
# 27    Bathurst Manor, Wilson Heights, Downsview North                    Bank
# 28                                   Thorncliffe Park          Sandwich Place
# 29                           Richmond, Adelaide, King             Coffee Shop
# 30                       Dufferin, Dovercourt Village                  Bakery
# 31                                Scarborough Village           Jewelry Store
# 32                       Fairview, Henry Farm, Oriole          Clothing Store
# 33                    Northwood Park, York University  Furniture / Home Store
# 34                                 The Danforth  East                    Park
# 35  Harbourfront East, Union Station, Toronto Islands             Coffee Shop
# 36                           Little Portugal, Trinity                     Bar
# 37        Kennedy Park, Ionview, East Birchmount Park        Department Store
# 38                                    Bayview Village                    Café
# 39                                     Downsview East                    Park
# 40                       The Danforth West, Riverdale        Greek Restaurant
# 41           Toronto Dominion Centre, Design Exchange             Coffee Shop
# 42       Brockton, Parkdale Village, Exhibition Place                    Café
# 43                    Golden Mile, Clairlea, Oakridge                  Bakery
# 44                                     Downsview West           Grocery Store
# 45                     India Bazaar, The Beaches West                    Park
# 46                     Commerce Court, Victoria Hotel             Coffee Shop
# 47           North Park, Maple Leaf Park, Upwood Park        Basketball Court
# 48                                      Humber Summit  Furniture / Home Store
# 49    Cliffside, Cliffcrest, Scarborough Village West                   Motel
# 50                            Willowdale, Newtonbrook               Piano Bar
# 52                                    Studio District             Coffee Shop
# 53                  Bedford Park, Lawrence Manor East          Sandwich Place
# 54   Del Ray, Mount Dennis, Keelsdale and Silverthorn              Restaurant
# 56                        Birch Cliff, Cliffside West                    Café
# 57                                   Willowdale South        Ramen Restaurant
# 58                                Downsview Northwest      Athletics & Sports
# 59                                      Lawrence Park                    Park
# 60                                           Roselawn    Fast Food Restaurant
# 61                      Runnymede, The Junction North                 Brewery
# 63  Dorset Park, Wexford Heights, Scarborough Town...       Indian Restaurant
# 65                                   Davisville North                    Park
# 66                           Forest Hill North & West        Sushi Restaurant
# 67                      High Park, The Junction South                    Café
# 68                                          Westmount             Pizza Place
# 69                                  Wexford, Maryvale              Smoke Shop
# 70                                    Willowdale West                Pharmacy
# 71                                 North Toronto West             Coffee Shop
# 72                The Annex, North Midtown, Yorkville                    Café
# 73                             Parkdale, Roncesvalles          Breakfast Spot
# 74                                     Enclave of L4W             Coffee Shop
# 75  Kingsview Village, St. Phillips, Martin Grove ...                    Park
# 76                                          Agincourt                  Lounge
# 77                                         Davisville          Sandwich Place
# 78                     University of Toronto, Harbord                    Café
# 79                                 Runnymede, Swansea             Coffee Shop
# 80            Clarks Corners, Tam O'Shanter, Sullivan    Fast Food Restaurant
# 81                        Moore Park, Summerhill East                    Park
# 82          Kensington Market, Chinatown, Grange Park                    Café
# 83  Milliken, Agincourt North, Steeles East, L'Amo...                    Park
# 84  Summerhill West, Rathnelly, South Hill, Forest...             Coffee Shop
# 85  CN Tower, King and Spadina, Railway Lands, Har...        Airport Terminal
# 86       New Toronto, Mimico South, Humber Bay Shores                     Gym
# 87  South Steeles, Silverstone, Humbergate, Jamest...           Grocery Store
# 88                      Steeles West, L'Amoreaux West    Fast Food Restaurant
# 90                                     Enclave of M5E             Coffee Shop
# 91                             Alderwood, Long Branch             Pizza Place
# 92  Clairville, Humberwood, Woodbine Downs, West H...              Truck Stop
# 93                        St. James Town, Cabbagetown             Coffee Shop
# 94             First Canadian Place, Underground city             Coffee Shop
# 96                               Church and Wellesley             Coffee Shop
# 97                                     Enclave of M4L      Light Rail Station
# 99  Mimico NW, The Queensway West, South of Bloor,...           Grocery Store
#
#     2nd Most Common Venue       3rd Most Common Venue  \
# 0                    Park        Fast Food Restaurant
# 1   Portuguese Restaurant                Intersection
# 2                    Park                      Bakery
# 3       Accessories Store      Furniture / Home Store
# 4        Sushi Restaurant                 Yoga Studio
# 5     Dumpling Restaurant              Discount Store
# 6    Caribbean Restaurant         Japanese Restaurant
# 7    Gym / Fitness Center                   Gastropub
# 8          Clothing Store                       Hotel
# 9                  Bakery            Sushi Restaurant
# 10    Dumpling Restaurant              Discount Store
# 12                    Gym                 Coffee Shop
# 13           Skating Rink                 Curling Ice
# 14                   Café                Cocktail Bar
# 15           Hockey Arena                       Trail
# 16               Pharmacy                Liquor Store
# 17                   Bank         Rental Car Location
# 18                    Pub                       Trail
# 19           Cocktail Bar                      Bakery
# 21               Pharmacy       Korean BBQ Restaurant
# 22    Sporting Goods Shop                        Bank
# 23                   Café          Italian Restaurant
# 24                   Café                        Park
# 25    Fried Chicken Joint            Hakka Restaurant
# 26            Golf Course                     Dog Run
# 27            Coffee Shop           Mobile Phone Shop
# 28      Indian Restaurant                 Yoga Studio
# 29                   Café                  Restaurant
# 30               Pharmacy                 Music Venue
# 31             Playground               Women's Store
# 32            Coffee Shop        Fast Food Restaurant
# 33            Coffee Shop              Massage Studio
# 34           Intersection           Convenience Store
# 35               Aquarium                        Café
# 36            Coffee Shop                  Restaurant
# 37      Convenience Store          Chinese Restaurant
# 38     Chinese Restaurant         Japanese Restaurant
# 39       Business Service                     Airport
# 40            Coffee Shop          Italian Restaurant
# 41                  Hotel                        Café
# 42            Coffee Shop                      Bakery
# 43           Soccer Field                Intersection
# 44                   Park                       Hotel
# 45         Sandwich Place        Fast Food Restaurant
# 46             Restaurant                       Hotel
# 47                   Park  Construction & Landscaping
# 48             Restaurant                 Pizza Place
# 49           Skating Rink         American Restaurant
# 50          Women's Store         Dumpling Restaurant
# 52    American Restaurant                        Café
# 53     Italian Restaurant                  Restaurant
# 54         Discount Store              Sandwich Place
# 56  General Entertainment                Skating Rink
# 57            Coffee Shop               Shopping Mall
# 58           Liquor Store              Discount Store
# 59               Bus Line                 Swim School
# 60                   Pool                      Garden
# 61          Grocery Store           Convenience Store
# 63              Pet Store       Vietnamese Restaurant
# 65            Pizza Place                       Hotel
# 66     Mexican Restaurant               Jewelry Store
# 67     Mexican Restaurant             Thai Restaurant
# 68         Discount Store                Intersection
# 69         Sandwich Place           Accessories Store
# 70            Pizza Place                 Coffee Shop
# 71         Clothing Store                 Yoga Studio
# 72         Sandwich Place                 Coffee Shop
# 73              Gift Shop                   Bookstore
# 74                  Hotel                         Gym
# 75      Mobile Phone Shop              Sandwich Place
# 76           Skating Rink              Breakfast Spot
# 77            Pizza Place                Dessert Shop
# 78              Bookstore                      Bakery
# 79                   Café            Sushi Restaurant
# 80            Pizza Place                 Gas Station
# 81                  Trail                  Restaurant
# 82            Coffee Shop       Vietnamese Restaurant
# 83    Arts & Crafts Store                Intersection
# 84    Fried Chicken Joint         American Restaurant
# 85         Airport Lounge             Harbor / Marina
# 86            Coffee Shop        Fast Food Restaurant
# 87            Pizza Place        Fast Food Restaurant
# 88               Gym Pool              Sandwich Place
# 90     Seafood Restaurant                Cocktail Bar
# 91             Playground                Skating Rink
# 92    Rental Car Location               Garden Center
# 93            Pizza Place                        Café
# 94                   Café                       Hotel
# 96       Sushi Restaurant         Japanese Restaurant
# 97            Yoga Studio               Auto Workshop
# 99            Social Club              Discount Store
#
#             4th Most Common Venue        5th Most Common Venue
# 0              Falafel Restaurant                  Event Space
# 1      Financial or Legal Service                  Coffee Shop
# 2                  Breakfast Spot                         Café
# 3                        Boutique        Vietnamese Restaurant
# 4              Persian Restaurant                     Beer Bar
# 5             Distribution Center                      Dog Run
# 6                            Café                Women's Store
# 7                    Intersection               Breakfast Spot
# 8                 Bubble Tea Shop           Italian Restaurant
# 9             Japanese Restaurant         Ethiopian Restaurant
# 10            Distribution Center                      Dog Run
# 12                  Grocery Store             Sushi Restaurant
# 13                    Video Store           Athletics & Sports
# 14                      Gastropub                   Restaurant
# 15            Dumpling Restaurant               Discount Store
# 16                    Coffee Shop               Shopping Plaza
# 17              Electronics Store               Breakfast Spot
# 18                  Women's Store                    Drugstore
# 19                       Beer Bar               Farmers Market
# 21                  Women's Store                    Drugstore
# 22                   Burger Joint                Shopping Mall
# 23                 Sandwich Place          Japanese Restaurant
# 24                     Restaurant                    Nightclub
# 25           Caribbean Restaurant                       Bakery
# 26       Mediterranean Restaurant                         Pool
# 27               Sushi Restaurant                 Intersection
# 28      Middle Eastern Restaurant                 Burger Joint
# 29                            Gym               Clothing Store
# 30      Middle Eastern Restaurant                  Supermarket
# 31                 Discount Store          Distribution Center
# 32                     Restaurant                Women's Store
# 33                            Bar           Miscellaneous Shop
# 34                  Metro Station                Women's Store
# 35                          Hotel                   Restaurant
# 36          Vietnamese Restaurant                         Café
# 37                     Hobby Shop                  Coffee Shop
# 38                           Bank               Discount Store
# 39                  Women's Store          Dumpling Restaurant
# 40         Furniture / Home Store               Ice Cream Shop
# 41             Italian Restaurant                   Restaurant
# 42                 Breakfast Spot                Grocery Store
# 43                           Park                Metro Station
# 44                  Shopping Mall                         Bank
# 45                            Pub                      Brewery
# 46                           Café                          Gym
# 47                         Bakery  Eastern European Restaurant
# 48               Doner Restaurant                 Dessert Shop
# 49                  Women's Store                   Donut Shop
# 50                 Discount Store          Distribution Center
# 52                      Gastropub                       Bakery
# 53                    Coffee Shop                  Pizza Place
# 54                    Coffee Shop                Women's Store
# 56                College Stadium                 Concert Hall
# 57                           Café                  Pizza Place
# 58                  Grocery Store          Dumpling Restaurant
# 59                  Women's Store                   Donut Shop
# 60                   Home Service         Ethiopian Restaurant
# 61                  Women's Store          Distribution Center
# 63             Chinese Restaurant                  Gaming Cafe
# 65              Food & Drink Shop               Sandwich Place
# 66                          Trail                Women's Store
# 67           Fast Food Restaurant                  Flea Market
# 68      Middle Eastern Restaurant               Sandwich Place
# 69      Middle Eastern Restaurant                       Bakery
# 70                    Supermarket                Women's Store
# 71                     Restaurant           Mexican Restaurant
# 72                    Pizza Place                    BBQ Joint
# 73                    Coffee Shop                   Restaurant
# 74                   Intersection    Middle Eastern Restaurant
# 75                  Women's Store                   Donut Shop
# 76      Latin American Restaurant           Falafel Restaurant
# 77                            Gym                         Café
# 78                            Bar          Japanese Restaurant
# 79             Italian Restaurant                          Pub
# 80                           Bank           Italian Restaurant
# 81                            Gym                    Drugstore
# 82  Vegetarian / Vegan Restaurant                          Bar
# 83                     Playground                    Drugstore
# 84                   Liquor Store                         Bank
# 85                    Coffee Shop                        Plane
# 86             Mexican Restaurant                       Bakery
# 87                       Pharmacy                   Beer Store
# 88                 Breakfast Spot                     Pharmacy
# 90                         Bakery                   Restaurant
# 91                            Gym                  Coffee Shop
# 92                      Drugstore                   Donut Shop
# 93             Italian Restaurant                       Bakery
# 94            Japanese Restaurant                   Restaurant
# 96                     Restaurant                      Gay Bar
# 97                  Garden Center                       Garden
# 99                         Bakery                Tanning Salon

# %%
print("Cluster 3")
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# Cluster 3
#                                          Neighborhood 1st Most Common Venue  \
# 51                                  Downsview Central        Baseball Field
# 55                                   Humberlea, Emery        Baseball Field
# 98  Old Mill South, King's Mill Park, Sunnylea, Hu...        Baseball Field
#
#           2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 51                   Food Truck      Business Service           Event Space
# 55  Eastern European Restaurant   Distribution Center               Dog Run
# 98             Business Service        Farmers Market    Falafel Restaurant
#
#    5th Most Common Venue
# 51  Ethiopian Restaurant
# 55      Doner Restaurant
# 98           Event Space

# %%
print("Cluster 4")
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# Cluster 4
#                                      Neighborhood 1st Most Common Venue  \
# 95  The Kingsway, Montgomery Road, Old Mill North                 River
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 95             Drugstore                 Diner        Discount Store
#
#    5th Most Common Venue
# 95   Distribution Center

# %%
print("Cluster 5")
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# Cluster 5
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 20  Caledonia-Fairbanks                  Park         Women's Store
# 62               Weston                  Park         Women's Store
# 64      York Mills West                  Park     Convenience Store
# 89             Rosedale                  Park            Playground
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 20   Dumpling Restaurant        Discount Store   Distribution Center
# 62   Dumpling Restaurant        Discount Store   Distribution Center
# 64         Women's Store   Dumpling Restaurant        Discount Store
# 89                 Trail            Donut Shop                 Diner
